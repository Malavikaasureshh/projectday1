# %%
pip install pandas matplotlib seaborn scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      --------- --------------------------- 41.0/167.0 kB 991.0 kB/s eta 0:00:01
#      -------------- ------------------------ 61.4/167.0 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 6.3 MB/s eta 0:00:02
#     --------------------------------------- 0.2/11.5 MB 4.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/11.5 MB 4.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.5 MB 5.4 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/11.5 MB 5.4 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Malavika suresh\Downloads\test.csv')

# %%
data.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
data.isnull().sum()
# Out:
# age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    0
# dtype: int64

# %%
data=data.drop_duplicates()

# %%
data.dtypes
# Out:
# age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    object
# dtype: object

# %%
print(data.columns)
# Out:
# Index(['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"'], dtype='object')

# %%
# Summary statistics for numerical columns
numerical_summary = data.describe()

# Summary for categorical columns
categorical_summary = data.describe(include='object')

# Print both summaries
print("Numerical Summary:\n", numerical_summary)
print("\nCategorical Summary:\n", categorical_summary)
# Out:
# Numerical Summary:
#         age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# count                                                4521
# unique                                               4521
# top     44;"entrepreneur";"single";"tertiary";"no";113...
# freq                                                    1
#
# Categorical Summary:
#         age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# count                                                4521
# unique                                               4521
# top     44;"entrepreneur";"single";"tertiary";"no";113...
# freq                                                    1

# %%
# Reload the dataset with the correct delimiter
data = pd.read_csv(r'C:\Users\Malavika suresh\Downloads\test.csv', delimiter=';')

# Check the columns again
print(data.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualizing the distribution of the target variable
sns.countplot(x='y', data=data)
plt.title('Distribution of Target Variable (y)')
plt.show()

# %%
# Age and target relationship
sns.boxplot(x='y', y='age', data=data)
plt.title('Age Distribution by Target Variable (y)')
plt.show()

# Mean age by target variable
age_mean = data.groupby('y')['age'].mean()
print("Mean Age by Target Variable (y):\n", age_mean)
# Out:
# Mean Age by Target Variable (y):
#  y
# no     40.998000
# yes    42.491363
# Name: age, dtype: float64

# %%
# Balance and target relationship
sns.boxplot(x='y', y='balance', data=data)
plt.title('Balance Distribution by Target Variable (y)')
plt.show()

# Mean balance by target variable
balance_mean = data.groupby('y')['balance'].mean()
print("Mean Balance by Target Variable (y):\n", balance_mean)
# Out:
# Mean Balance by Target Variable (y):
#  y
# no     1403.211750
# yes    1571.955854
# Name: balance, dtype: float64

# %%
# Job categories distribution by target variable
job_target_distribution = data.groupby(['job', 'y']).size().unstack()
job_target_distribution.plot(kind='bar', stacked=True, figsize=(10, 7))
plt.title('Job Categories by Target Variable (y)')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only the numerical columns
numerical_data = data.select_dtypes(include=['float64', 'int64'])

# Correlation matrix for numerical variables
correlation_matrix = numerical_data.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
data=data=pd.read_csv(r'C:\Users\Malavika suresh\Downloads\test.csv')

# %%
data.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
data.isnull().sum()
# Out:
# age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    0
# dtype: int64

# %%
data=data.drop_duplicates()

# %%
data.dtypes
# Out:
# age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    object
# dtype: object

# %%
print(data.columns)
# Out:
# Index(['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"'], dtype='object')

# %%
# Reload the dataset with the correct delimiter
data = pd.read_csv(r'C:\Users\Malavika suresh\Downloads\test.csv', delimiter=';')

# Check the columns again
print(data.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
# Summary statistics for numerical columns
numerical_summary = data.describe()

# Summary for categorical columns
categorical_summary = data.describe(include='object')

# Print both summaries
print("Numerical Summary:\n", numerical_summary)
print("\nCategorical Summary:\n", categorical_summary)
# Out:
# Numerical Summary:
#                 age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualizing the distribution of the target variable
sns.countplot(x='y', data=data)
plt.title('Distribution of Target Variable (y)')
plt.show()

# %%
# Age and target relationship
sns.boxplot(x='y', y='age', data=data)
plt.title('Age Distribution by Target Variable (y)')
plt.show()

# Mean age by target variable
age_mean = data.groupby('y')['age'].mean()
print("Mean Age by Target Variable (y):\n", age_mean)
# Out:
# Mean Age by Target Variable (y):
#  y
# no     40.998000
# yes    42.491363
# Name: age, dtype: float64

# %%
# Balance and target relationship
sns.boxplot(x='y', y='balance', data=data)
plt.title('Balance Distribution by Target Variable (y)')
plt.show()

# Mean balance by target variable
balance_mean = data.groupby('y')['balance'].mean()
print("Mean Balance by Target Variable (y):\n", balance_mean)
# Out:
# Mean Balance by Target Variable (y):
#  y
# no     1403.211750
# yes    1571.955854
# Name: balance, dtype: float64

# %%
# Job categories distribution by target variable
job_target_distribution = data.groupby(['job', 'y']).size().unstack()
job_target_distribution.plot(kind='bar', stacked=True, figsize=(10, 7))
plt.title('Job Categories by Target Variable (y)')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only the numerical columns
numerical_data = data.select_dtypes(include=['float64', 'int64'])

# Correlation matrix for numerical variables
correlation_matrix = numerical_data.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()
